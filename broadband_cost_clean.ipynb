# %%
import pandas as pd
import numpy as np

df = pd.read_csv('broadband_data_opendatachallenge.csv', encoding='latin1')

df.replace(['NULL', 'null', '', ' '], np.nan, inplace=True)

df.dropna(axis=0, how='any', inplace=True)

df.reset_index(drop=True, inplace=True)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24219 entries, 0 to 24218
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Zip                                       24219 non-null  int64
#  1   Population                                24219 non-null  float64
#  2   County                                    24219 non-null  object
#  3   State                                     24219 non-null  object
#  4   WiredCount_2020                           24219 non-null  float64
#  5   Fwcount_2020                              24219 non-null  float64
#  6   AllProviderCount_2020                     24219 non-null  float64
#  7   Wired25_3_2020                            24219 non-null  float64
#  8   Wired100_3_2020                           24219 non-null  float64
#  9   All25_3_2020                              24219 non-null  float64
#  10  All100_3                                  24219 non-null  float64
#  11  TestCount                                 24219 non-null  float64
#  12  AverageMbps                               24219 non-null  float64
#  13  FastestAverageMbps                        24219 non-null  float64
#  14  %Access to Terrestrial Broadband          24219 non-null  object
#  15  Lowest Priced Terrestrial Broadband Plan  24219 non-null  float64
#  16  WiredCount_2015                           24219 non-null  float64
#  17  Fwcount_2015                              24219 non-null  float64
#  18  AllProviderCount_2015                     24219 non-null  float64
#  19  Wired25_3_2015                            24219 non-null  float64
#  20  Wired100_3_2015                           24219 non-null  float64
#  21  All25_3_2015                              24219 non-null  float64
#  22  All100_3.1                                24219 non-null  float64
# dtypes: float64(19), int64(1), object(3)
# memory usage: 4.2+ MB
#      Zip  Population     County           State  WiredCount_2020  \
# 0  29620     12934.0  Abbeville  South Carolina              6.0
# 1  29628      2759.0  Abbeville  South Carolina              4.0
# 2  29638      2944.0  Abbeville  South Carolina              6.0
# 3  29639      1742.0  Abbeville  South Carolina              3.0
# 4  70516      1546.0     Acadia       Louisiana              4.0
#
#    Fwcount_2020  AllProviderCount_2020  Wired25_3_2020  Wired100_3_2020  \
# 0           0.0                   11.0             5.0              3.0
# 1           0.0                    8.0             3.0              2.0
# 2           1.0                   13.0             4.0              4.0
# 3           0.0                    8.0             3.0              3.0
# 4           3.0                   12.0             2.0              2.0
#
#    All25_3_2020  ...  FastestAverageMbps  %Access to Terrestrial Broadband  \
# 0           7.0  ...              536.35                               98%
# 1           5.0  ...              126.06                               95%
# 2           6.0  ...              222.35                               95%
# 3           5.0  ...              223.75                               90%
# 4           4.0  ...                9.41                               33%
#
#    Lowest Priced Terrestrial Broadband Plan  WiredCount_2015 Fwcount_2015  \
# 0                                     40.00              6.0          0.0
# 1                                     40.00              4.0          0.0
# 2                                     40.00              5.0          0.0
# 3                                     40.00              3.0          0.0
# 4                                     69.99              4.0          2.0
#
#    AllProviderCount_2015  Wired25_3_2015  Wired100_3_2015  All25_3_2015  \
# 0                    8.0             3.0              3.0           3.0
# 1                    6.0             3.0              3.0           3.0
# 2                    7.0             2.0              2.0           2.0
# 3                    5.0             3.0              3.0           3.0
# 4                    8.0             2.0              1.0           2.0
#
#    All100_3.1
# 0         3.0
# 1         3.0
# 2         2.0
# 3         3.0
# 4         1.0
#
# [5 rows x 23 columns]
