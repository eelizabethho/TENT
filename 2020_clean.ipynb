# %%
import pandas as pd

df = pd.read_csv("broadband_data_2020October.csv")

df = df.dropna()
df.columns = df.columns.str.strip()
df['ST'] = df['ST'].str.strip()
df = df[df['ST'] == 'VA']
df = df.reset_index(drop=True)

print(df.head(150))
# Out:
#      ST  COUNTY ID          COUNTY NAME BROADBAND AVAILABILITY PER FCC  \
# 0    VA      51001      Accomack County                         0.9048
# 1    VA      51003     Albemarle County                         0.9258
# 2    VA      51005     Alleghany County                         0.9362
# 3    VA      51007        Amelia County                         0.7044
# 4    VA      51009       Amherst County                         0.9422
# ..   ..        ...                  ...                            ...
# 128  VA      51800         Suffolk city                         0.9461
# 129  VA      51810  Virginia Beach city                         0.9832
# 130  VA      51820      Waynesboro city                         0.9838
# 131  VA      51830    Williamsburg city                         0.7844
# 132  VA      51840      Winchester city                         0.9978
#
#     BROADBAND USAGE
# 0             0.169
# 1             0.536
# 2             0.706
# 3             0.154
# ...
